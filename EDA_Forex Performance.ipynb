# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %config Completer.use_jedi = False

# %%
forex=pd.read_html("C:/Users/Joema/Desktop/Python Codes/Docs_Analysis/Statement.htm", header=2,)
fx=forex[0]
fx.index=fx['Open Time']
fx.head()
# Out:
#                        Ticket            Open Time     Type  \
# Open Time
# 2020.03.26 15:52:18  10716327  2020.03.26 15:52:18  balance
# 2020.03.27 16:00:06  10778802  2020.03.27 16:00:06      buy
# 2020.03.27 16:00:06  10778804  2020.03.27 16:00:06  balance
# 2020.03.27 16:15:10  10780036  2020.03.27 16:15:10  balance
# 2020.03.27 16:56:52  10782546  2020.03.27 16:56:52      buy
#
#                                             Size                         Item  \
# Open Time
# 2020.03.26 15:52:18                >Card Deposit                >Card Deposit
# 2020.03.27 16:00:06                         0.30                       eurusd
# 2020.03.27 16:00:06  >10778802 Spread Cost -2.70  >10778802 Spread Cost -2.70
# 2020.03.27 16:15:10  >10778802 Spread Cost -2.40  >10778802 Spread Cost -2.40
# 2020.03.27 16:56:52                         0.30                       eurusd
#
#                                            Price                        S / L  \
# Open Time
# ...

# %%
fx.info()
fx.nunique()
#uber['Date/Time']=pd.to_datetime(uber['Date/Time'])
#uber.Base=uber.Base.astype('category')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 743 entries, 2020.03.26 15:52:18 to Balance:
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Ticket      680 non-null    object
#  1   Open Time   680 non-null    object
#  2   Type        680 non-null    object
#  3   Size        680 non-null    object
#  4   Item        680 non-null    object
#  5   Price       680 non-null    object
#  6   S / L       680 non-null    object
#  7   T / P       680 non-null    object
#  8   Close Time  678 non-null    object
#  9   Price.1     679 non-null    object
#  10  Commission  740 non-null    object
#  11  Taxes       740 non-null    object
#  12  Swap        740 non-null    object
#  13  Profit      680 non-null    object
# dtypes: object(14)
# memory usage: 87.1+ KB
# Ticket        679
# Open Time     476
# Type           12
# Size          450
# Item          444
# Price         649
# S / L         570
# ...

# %%
fx_type=fx.Type.copy()
fx_type.dropna(inplace=True)
fx_type.value_counts()
#fx.dropna(how='any',inplace=True)
#fx.Type!='balance'
#fx[fx.Type!='balance']
# Out:
# balance            453
# buy                127
# sell                90
# Type                 2
# Open Trades:         1
# 1 467.38             1
# Summary:             1
# 351.77               1
# Working Orders:      1
# -1 115.61            1
# Closed P/L:          1
# No transactions      1
# Name: Type, dtype: int64

# %%
fx.dropna(axis=0,how='all',subset=['Type'],inplace=True)
fx.tail(12)
# Out:
#                                   Ticket            Open Time  \
# Open Time
# 2021.03.03 02:51:39             17214136  2021.03.03 02:51:39
# Closed P/L:                  Closed P/L:          Closed P/L:
# Open Trades:                Open Trades:         Open Trades:
# Open Time                         Ticket            Open Time
# 2021.03.03 02:51:39             17214135  2021.03.03 02:51:39
# Working Orders:          Working Orders:      Working Orders:
# Open Time                         Ticket            Open Time
# No transactions          No transactions      No transactions
# Summary:                        Summary:             Summary:
# Deposit/Withdrawal:  Deposit/Withdrawal:  Deposit/Withdrawal:
# Closed Trade P/L:      Closed Trade P/L:    Closed Trade P/L:
# Balance:                        Balance:             Balance:
#
#                                 Type                         Size  \
# Open Time
# 2021.03.03 02:51:39          balance  >17214135 Spread Cost -0.52
# ...

# %%
fx.drop(fx.index[-11:], inplace=True)
fx.head()
# Out:
#                        Ticket            Open Time     Type  \
# Open Time
# 2020.03.26 15:52:18  10716327  2020.03.26 15:52:18  balance
# 2020.03.27 16:00:06  10778802  2020.03.27 16:00:06      buy
# 2020.03.27 16:00:06  10778804  2020.03.27 16:00:06  balance
# 2020.03.27 16:15:10  10780036  2020.03.27 16:15:10  balance
# 2020.03.27 16:56:52  10782546  2020.03.27 16:56:52      buy
#
#                                             Size                         Item  \
# Open Time
# 2020.03.26 15:52:18                >Card Deposit                >Card Deposit
# 2020.03.27 16:00:06                         0.30                       eurusd
# 2020.03.27 16:00:06  >10778802 Spread Cost -2.70  >10778802 Spread Cost -2.70
# 2020.03.27 16:15:10  >10778802 Spread Cost -2.40  >10778802 Spread Cost -2.40
# 2020.03.27 16:56:52                         0.30                       eurusd
#
#                                            Price                        S / L  \
# Open Time
# ...

# %%
fx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 668 entries, 2020.03.26 15:52:18 to 2021.03.02 09:20:47
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Ticket      668 non-null    object
#  1   Open Time   668 non-null    object
#  2   Type        668 non-null    object
#  3   Size        668 non-null    object
#  4   Item        668 non-null    object
#  5   Price       668 non-null    object
#  6   S / L       668 non-null    object
#  7   T / P       668 non-null    object
#  8   Close Time  668 non-null    object
#  9   Price.1     668 non-null    object
#  10  Commission  668 non-null    object
#  11  Taxes       668 non-null    object
#  12  Swap        668 non-null    object
#  13  Profit      668 non-null    object
# dtypes: object(14)
# memory usage: 78.3+ KB

# %%
trades=fx[fx.Type!='balance']
trades.head(10)
# Out:
#                        Ticket            Open Time  Type  Size    Item  \
# Open Time
# 2020.03.27 16:00:06  10778802  2020.03.27 16:00:06   buy  0.30  eurusd
# 2020.03.27 16:56:52  10782546  2020.03.27 16:56:52   buy  0.30  eurusd
# 2020.03.30 01:32:00  10811982  2020.03.30 01:32:00  sell  0.30  usdjpy
# 2020.03.30 18:25:08  10846177  2020.03.30 18:25:08  sell  0.30  eurusd
# 2020.03.31 06:06:07  10875173  2020.03.31 06:06:07  sell  0.10  eurusd
# 2020.03.31 15:48:31  10902690  2020.03.31 15:48:31  sell  0.20  eurusd
# 2020.03.31 17:41:27  10908928  2020.03.31 17:41:27  sell  0.20  eurusd
# 2020.03.31 18:55:31  10912895  2020.03.31 18:55:31  sell  0.30  usdjpy
# 2020.03.31 20:09:15  10916244  2020.03.31 20:09:15  sell  0.30  usdjpy
# 2020.03.31 22:02:27  10919187  2020.03.31 22:02:27  sell  0.30  eurusd
#
#                        Price    S / L    T / P           Close Time  Price.1  \
# Open Time
# 2020.03.27 16:00:06  1.10605  1.10253  1.10888  2020.03.27 16:15:10  1.10691
# ...

# %%
trades.Commission.nunique()
trades.Taxes.nunique()
trades.Swap.nunique()
commission=trades.pop('Commission')
taxes=trades.pop('Taxes')
swaps=trades.pop('Swap')
tickets=trades.pop('Ticket')

# %%
trades.info()
trades.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 216 entries, 2020.03.27 16:00:06 to 2021.03.02 03:36:49
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Open Time   216 non-null    object
#  1   Type        216 non-null    object
#  2   Size        216 non-null    object
#  3   Item        216 non-null    object
#  4   Price       216 non-null    object
#  5   S / L       216 non-null    object
#  6   T / P       216 non-null    object
#  7   Close Time  216 non-null    object
#  8   Price.1     216 non-null    object
#  9   Profit      216 non-null    object
# dtypes: object(10)
# memory usage: 18.6+ KB
#                                Open Time  Type  Size    Item    Price  \
# Open Time
# 2020.03.27 16:00:06  2020.03.27 16:00:06   buy  0.30  eurusd  1.10605
# 2020.03.27 16:56:52  2020.03.27 16:56:52   buy  0.30  eurusd  1.10819
# 2020.03.30 01:32:00  2020.03.30 01:32:00  sell  0.30  usdjpy  107.394
# ...

# %%
buy_trades=trades[trades.Type=='buy']
sell_trades=trades[trades.Type=='sell']

# %%
sell_trades
buy_trades
# Out:
#                                Open Time  Type  Size    Item    Price  \
# Open Time
# 2020.03.30 01:32:00  2020.03.30 01:32:00  sell  0.30  usdjpy  107.394
# 2020.03.30 18:25:08  2020.03.30 18:25:08  sell  0.30  eurusd  1.10388
# 2020.03.31 06:06:07  2020.03.31 06:06:07  sell  0.10  eurusd  1.10171
# 2020.03.31 15:48:31  2020.03.31 15:48:31  sell  0.20  eurusd  1.10056
# 2020.03.31 17:41:27  2020.03.31 17:41:27  sell  0.20  eurusd  1.09677
# ...                                  ...   ...   ...     ...      ...
# 2020.09.22 00:12:44  2020.09.22 00:12:44  sell  0.04  gbpusd  1.28071
# 2020.09.28 03:35:25  2020.09.28 03:35:25  sell  0.03  eurgbp  0.91118
# 2020.09.28 03:37:46  2020.09.28 03:37:46  sell  0.01  gbpusd  1.27660
# 2021.03.01 01:58:28  2021.03.01 01:58:28  sell  0.07  usdchf  0.90740
# 2021.03.02 03:36:49  2021.03.02 03:36:49  sell  0.08  eurusd  1.20322
#
#                        S / L    T / P           Close Time  Price.1   Profit
# Open Time
# ...

# %%
sell_trades.index=pd.to_datetime(sell_trades.index)
sell_trades['Open Time']=pd.to_datetime(sell_trades['Open Time'])
sell_trades['Close Time']=pd.to_datetime(sell_trades['Close Time'])
sell_trades.Type=sell_trades.Type.astype('category')
sell_trades.Size=sell_trades.Size.astype('float')
sell_trades.Item=sell_trades.Item.astype('category')
sell_trades.Price=sell_trades.Price.astype('float')
sell_trades['S / L']=sell_trades['S / L'].astype('float')
sell_trades['T / P']=sell_trades['T / P'].astype('float')
sell_trades['Price.1']=sell_trades['Price.1'].astype('float')
sell_trades.Profit=sell_trades.Profit.astype('float')
# Out:
# <ipython-input-31-42d602eedb34>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sell_trades['Open Time']=pd.to_datetime(sell_trades['Open Time'])
# <ipython-input-31-42d602eedb34>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sell_trades['Close Time']=pd.to_datetime(sell_trades['Close Time'])
# C:\Users\Joema\anaconda3\envs\pandas_playground\lib\site-packages\pandas\core\generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
sell_trades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90 entries, 2020-03-30 01:32:00 to 2021-03-02 03:36:49
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Open Time   90 non-null     datetime64[ns]
#  1   Type        90 non-null     category
#  2   Size        90 non-null     float64
#  3   Item        90 non-null     category
#  4   Price       90 non-null     float64
#  5   S / L       90 non-null     float64
#  6   T / P       90 non-null     float64
#  7   Close Time  90 non-null     datetime64[ns]
#  8   Price.1     90 non-null     float64
#  9   Profit      90 non-null     float64
# dtypes: category(2), datetime64[ns](2), float64(6)
# memory usage: 7.0 KB

# %%
buy_trades.index=pd.to_datetime(buy_trades.index)
buy_trades['Open Time']=pd.to_datetime(buy_trades['Open Time'])
buy_trades['Close Time']=pd.to_datetime(buy_trades['Close Time'])
buy_trades.Type=buy_trades.Type.astype('category')
buy_trades.Size=buy_trades.Size.astype('float')
buy_trades.Item=buy_trades.Item.astype('category')
buy_trades.Price=buy_trades.Price.astype('float')
buy_trades['S / L']=buy_trades['S / L'].astype('float')
buy_trades['T / P']=buy_trades['T / P'].astype('float')
buy_trades['Price.1']=buy_trades['Price.1'].astype('float')
buy_trades.Profit=buy_trades.Profit.astype('float')
# Out:
# <ipython-input-33-41aa5528303e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   buy_trades['Open Time']=pd.to_datetime(buy_trades['Open Time'])
# <ipython-input-33-41aa5528303e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   buy_trades['Close Time']=pd.to_datetime(buy_trades['Close Time'])
# C:\Users\Joema\anaconda3\envs\pandas_playground\lib\site-packages\pandas\core\generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
buy_trades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 126 entries, 2020-03-27 16:00:06 to 2021-03-01 03:10:58
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Open Time   126 non-null    datetime64[ns]
#  1   Type        126 non-null    category
#  2   Size        126 non-null    float64
#  3   Item        126 non-null    category
#  4   Price       126 non-null    float64
#  5   S / L       126 non-null    float64
#  6   T / P       126 non-null    float64
#  7   Close Time  126 non-null    datetime64[ns]
#  8   Price.1     126 non-null    float64
#  9   Profit      126 non-null    float64
# dtypes: category(2), datetime64[ns](2), float64(6)
# memory usage: 9.6 KB

# %%
del buy_trades['Open Time']
del sell_trades['Open Time']
def trade_result(profit):
    if profit>.00:
        return 'Win'
    else:
        return 'Lose'
buy_trades['W / L']=buy_trades.Profit.apply(trade_result)
sell_trades['W / L']=sell_trades.Profit.apply(trade_result)
# Out:
# <ipython-input-92-b8b721feb76d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   buy_trades['W / L']=buy_trades.Profit.apply(trade_result)
# <ipython-input-92-b8b721feb76d>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sell_trades['W / L']=sell_trades.Profit.apply(trade_result)

# %%
trades.index=pd.to_datetime(trades.index)
trades['Open Time']=pd.to_datetime(trades['Open Time'])
trades['Close Time']=pd.to_datetime(trades['Close Time'])
trades.Type=trades.Type.astype('category')
trades.Size=trades.Size.astype('float')
trades.Item=trades.Item.astype('category')
trades.Price=trades.Price.astype('float')
trades['S / L']=trades['S / L'].astype('float')
trades['T / P']=trades['T / P'].astype('float')
trades['Price.1']=trades['Price.1'].astype('float')
trades.Profit=trades.Profit.astype('float')
trades.head()
trades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 216 entries, 2020-03-27 16:00:06 to 2021-03-02 03:36:49
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Open Time   216 non-null    datetime64[ns]
#  1   Type        216 non-null    category
#  2   Size        216 non-null    float64
#  3   Item        216 non-null    category
#  4   Price       216 non-null    float64
#  5   S / L       216 non-null    float64
#  6   T / P       216 non-null    float64
#  7   Close Time  216 non-null    datetime64[ns]
#  8   Price.1     216 non-null    float64
#  9   Profit      216 non-null    float64
# dtypes: category(2), datetime64[ns](2), float64(6)
# memory usage: 16.1 KB
# <ipython-input-57-b82e696c6f80>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#defining function to create a W/L, Win/Lose Column
def trade_result(profit):
    if profit>.00:
        return 'Win'
    else:
        return 'Lose'

trades['W / L']=trades.Profit.apply(trade_result)
trades.head()
# Out:
# <ipython-input-59-d484ed341dca>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trades['W / L']=trades.Profit.apply(trade_result)
#                               Open Time  Type  Size    Item      Price  \
# Open Time
# 2020-03-27 16:00:06 2020-03-27 16:00:06   buy   0.3  eurusd    1.10605
# 2020-03-27 16:56:52 2020-03-27 16:56:52   buy   0.3  eurusd    1.10819
# 2020-03-30 01:32:00 2020-03-30 01:32:00  sell   0.3  usdjpy  107.39400
# 2020-03-30 18:25:08 2020-03-30 18:25:08  sell   0.3  eurusd    1.10388
# 2020-03-31 06:06:07 2020-03-31 06:06:07  sell   0.1  eurusd    1.10171
#
#                          S / L      T / P          Close Time    Price.1  \
# Open Time
# ...

# %%
#ploting type to show how often i buy vs. sell
trades.Type.value_counts().plot(legend=True,kind='pie',label='Buy & Sell Ratio')
# Out:
# <AxesSubplot:ylabel='Buy & Sell Ratio'>

# %%
#showing how often my W/L are on my buy orders
buy_trades['W / L'].value_counts().plot(kind='bar', label=)
# Out:
# <AxesSubplot:>
